# %%
import graphviz

f = graphviz.Digraph('finite_state_machine')

f.node("3","pyxem")
f.node("8","pyxem")
f.node("9","pyxem")
f.node("4","diffsims")
f.node("5","pixstem")
f.node("6","empyer")
f.node("7","orix")
f.edge("3","8")
f.edge("3","7")
f.edge("3","4")
f.edge("8","9")
f.edge("6","9")
f.edge("5","9")

# %%
f
